# %%
import sys
sys.path.append('../')

import numpy as np
#from scipy import ndimage

from skimage.filters import sobel_h
from skimage.filters import sobel_v
#from scipy import stats


import os
import matplotlib
import matplotlib.pyplot as plt
import scienceplots
from tensorflow.python.client import device_lib

#plt.rcParams['figure.figsize'] = [10,10]

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import decode_predictions
from tensorflow.keras.applications import ResNet50

from tensorflow.nn import depthwise_conv2d, relu
from tensorflow.math import multiply, reduce_sum, reduce_mean,reduce_euclidean_norm, sin, cos, abs
from tensorflow import stack, concat, expand_dims

import tensorflow_probability as tfp

from utils.utils import *
from scipy import ndimage, fft

plt.style.use(['science', 'ieee'])
plt.rcParams.update({'figure.dpi': '100'})

# %% [markdown]
# #### Experiment #1 : Confirming that most energy lies within the first 3 DCT coeficients

# %%
model = ResNet50(weights=None,
                  include_top=False,
                  input_shape=(224, 224, 3))
# Out:
# 2025-12-10 11:57:25.890262: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-10 11:57:25.926953: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-10 11:57:25.928369: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-10 11:57:25.929301: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2025-12-10 11:57:25.930141: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-10 11:57:25.931346: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-10 11:57:25.932519: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-10 11:57:25.934710: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2025-12-10 11:57:26.018206: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-10 11:57:26.019117: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-10 11:57:26.019937: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-10 11:57:26.020734: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8870 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5070, pci bus id: 0000:01:00.0, compute capability: 12.0

# %%
conv_layers = []
for l in model.layers:
	if 'conv2d' in str(type(l)).lower():
		if l.kernel_size == (3,3):
			conv_layers.append(l)

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox


#bars =  ax.bar(["dc", "c1", "c2", "c3", "c4", "c5", "c6", "c7", "c8"], vals)
pos = [(0,0) , (0,1), (1,0), (1,1), (0, 2) , (2, 0), (1,2), (2,1), (2,2) ]

d = []
for  i,j in pos:
	t = np.zeros((3,3))
	t[i,j] =1
	d.append(tf.reshape(fft.idctn(t, norm='ortho'), (3,3,1,1)))
d = tf.cast(tf.stack(d), dtype=tf.float32)

fig,ax= plt.subplots(1,1)


dct_mean = np.zeros((9))

for l_num in range(0, len(conv_layers)):
	


	f = get_filter(model, l_num)
	title = conv_layers[l_num].name
	w = tf.reshape(tf.reduce_sum(f*d, axis=(1,2)), (d.shape[0],1,1, f.shape[-2], f.shape[-1]))

	print(tf.math.reduce_sum(w**2))
	print(tf.math.reduce_sum(f**2))


	dct_mean += tf.reduce_sum(w**2, axis=(1,2,3,4))/tf.math.reduce_sum(w**2)

dct_mean /= len(conv_layers)

bars =  ax.bar(["dc", "c1", "c2", "c3", "c4", "c5", "c6", "c7", "c8"], dct_mean)


for i, bar in enumerate(bars):
	# Load image

	dct_im = np.zeros((3,3))
	dct_im[pos[i]]=1
	#print(idct2(np.float16(dct_im)))
	img = idct2(np.float16(dct_im))

	# Create OffsetImage object
	im = OffsetImage(img, zoom=3, cmap=plt.cm.binary)  # Adjust zoom for image size

	# Get the x position of the bar's center
	x_position = bar.get_x() + bar.get_width() / 2

	# Place image below the x-axis label
	ab = AnnotationBbox(im, (x_position, 0), 
						xybox=(0, -5),  # Adjust the second value for distance under the label
						xycoords='data', 
						boxcoords="offset points", 
						pad=0, frameon=True, 
						box_alignment=(0.5, 1))

	# Add image to the axes
	ax.add_artist(ab)
ax.set_xticklabels([''] * w.shape[0])  # Set empty labels
ax.set_xlabel('DCT Component')
ax.xaxis.set_label_coords(0.5, -0.15)
ax.set_ylabel('Avg. Energy \%')
ax.set_box_aspect(1)


ax.tick_params(axis='x', which='both', length=0)
ax.set_box_aspect(1)

ax.plot(ax.get_xticks(), [np.sum(dct_mean[:i+1]) for i in range(dct_mean.shape[-1])], lw=1, c='r', ls=':', marker='x', label="Cumulative Energy")
ax.legend()


fig.tight_layout()

plt.show()
# Out:
# 2025-12-10 11:57:26.743207: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2025-12-10 11:57:26.743223: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2025-12-10 11:57:26.743237: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2025-12-10 11:57:26.743250: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2025-12-10 11:57:26.743263: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2025-12-10 11:57:26.743274: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2025-12-10 11:57:26.743289: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2025-12-10 11:57:26.743520: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2025-12-10 11:57:26.744417: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:225] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 12.0
# 2025-12-10 11:57:26.744425: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:228] Used ptxas at ptxas
# 2025-12-10 11:57:26.744459: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 11:57:26.744468: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 11:57:26.744497: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 11:57:26.744508: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 11:57:26.744525: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 11:57:26.744532: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 11:57:26.744550: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-12-10 11:57:26.744602: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# /tmp/ipykernel_10614/2565881817.py:62: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] * w.shape[0])  # Set empty labels
# tf.Tensor(63.931324, shape=(), dtype=float32)
# tf.Tensor(63.931328, shape=(), dtype=float32)
# tf.Tensor(63.960197, shape=(), dtype=float32)
# tf.Tensor(63.960197, shape=(), dtype=float32)
# tf.Tensor(63.792656, shape=(), dtype=float32)
# tf.Tensor(63.792656, shape=(), dtype=float32)
# tf.Tensor(127.86147, shape=(), dtype=float32)
# tf.Tensor(127.86148, shape=(), dtype=float32)
# tf.Tensor(127.97917, shape=(), dtype=float32)
# tf.Tensor(127.979164, shape=(), dtype=float32)
# tf.Tensor(128.04498, shape=(), dtype=float32)
# tf.Tensor(128.04498, shape=(), dtype=float32)
# tf.Tensor(128.26529, shape=(), dtype=float32)
# tf.Tensor(128.26529, shape=(), dtype=float32)
# tf.Tensor(255.64679, shape=(), dtype=float32)
# tf.Tensor(255.64677, shape=(), dtype=float32)
# tf.Tensor(256.2361, shape=(), dtype=float32)
# tf.Tensor(256.2361, shape=(), dtype=float32)
# tf.Tensor(255.72336, shape=(), dtype=float32)
# tf.Tensor(255.72336, shape=(), dtype=float32)
# tf.Tensor(256.0661, shape=(), dtype=float32)
# tf.Tensor(256.0661, shape=(), dtype=float32)
# tf.Tensor(256.35547, shape=(), dtype=float32)
# tf.Tensor(256.35547, shape=(), dtype=float32)
# tf.Tensor(256.15765, shape=(), dtype=float32)
# tf.Tensor(256.15765, shape=(), dtype=float32)
# tf.Tensor(511.88605, shape=(), dtype=float32)
# tf.Tensor(511.88602, shape=(), dtype=float32)
# tf.Tensor(512.072, shape=(), dtype=float32)
# tf.Tensor(512.072, shape=(), dtype=float32)
# tf.Tensor(512.10187, shape=(), dtype=float32)
# tf.Tensor(512.10187, shape=(), dtype=float32)

# %%
fig.savefig('random_dct_full.pdf', dpi=600)

# %%
import pandas as pd
pd.DataFrame(dct_mean)
# Out:
#           0
# 0  0.111345
# 1  0.110707
# 2  0.110991
# 3  0.111105
# 4  0.111339
# 5  0.111146
# 6  0.111033
# 7  0.111026
# 8  0.111308

# %%
np.sum(dct_mean[0:3])
# Out:
# 0.33304292
